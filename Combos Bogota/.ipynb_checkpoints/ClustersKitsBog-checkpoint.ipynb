# %% [markdown]
# # Análisis de similitud entre clientres y combos por zonas

# %%
import pandas as pd

# %%
# Se leen los resultados
lift = pd.read_excel('result.xlsx', sheet_name = 'lift').to_dict(orient = 'index')
lift = { (lift[i]['product_a'], lift[i]['product_b']): lift[i]['lift']  for i in lift}
products = pd.read_excel('result.xlsx', sheet_name = 'products', index_col = 'id').to_dict(orient = 'index')

# %%
# Para cada producto se saca el kit representativo.
kits = []

for i in products:
    scores = [(100,i)]
    for j in products:
        try:
            scores.append((lift[i,j],j))
        except:
            scores.append((0,j))
    
    scores.sort(reverse = True)
    testKit = [ i[1] for i in scores[0:6] ]
    
    # Se eliminan kits repetidos
    inside = False
    for k in kits:
        if len(set(testKit).intersection(set(k))) > 3:
            inside = True
    
    if inside == False:
        kits.append([ i[1] for i in scores[0:6]])

print('Se crearon ', len(kits), ' kits')
# Out:
# Se crearon  15  kits

# %%
# Ahora se imprimen los kits con sus respectivas cantidades a comprar
pd.set_option('display.max_colwidth', 1000)

n = 1
for i in kits:
    
    print("\t")
    print('kit número ', n)
    print('porcentaje de compra ', sum([products[j]['orders'] for j in i])/6/535)
    name = [ products[j]['name'] for j in i ]
    category = [ products[j]['category'] for j in i ]
    quantity = [ round(products[j]['avg'],0) for j in i ]
    
    display(pd.DataFrame({'name': name, 'category': category, 'quantity': quantity}))
    n += 1
# Out:
#
# kit número  1
# porcentaje de compra  0.10218068535825545
#                                                               name                          category  quantity
# 0  Paquete de Codo 90° PVC Sanitario 40mm - 1-1/2" Cementar x 5 un  Accesorios Sanitaria/Ventilación       6.0
# 1      Paquete de Codo 45° PVC Sanitario 50mm - 2" Cementar x 5 un  Accesorios Sanitaria/Ventilación       3.0
# 2         Paquete de Cople PVC Sanitario 50mm - 2" Cementar x 5 un  Accesorios Sanitaria/Ventilación       4.0
# 3      Paquete de Codo 90° PVC Sanitario 50mm - 2" Cementar x 5 un  Accesorios Sanitaria/Ventilación       5.0
# 4     Paquete de Codo 45° PVC Sanitario 110mm - 4" Cementar x 5 un  Accesorios Sanitaria/Ventilación       3.0
# 5     Paquete de Codo 90° PVC Sanitario 110mm - 4" Cementar x 5 un  Accesorios Sanitaria/Ventilación       3.0
#
# kit número  2
# porcentaje de compra  0.2
#                                                        name                          category  quantity
# 0                                       Yeso Blanco x 40 kg                     Yesos y Cales       8.0
# 1                    Cemento Mortero Óptimo Tolteca x 50 kg                          Cementos       7.0
# 2                Cemento Gris Tolteca Extra CPC 30R x 50 kg                          Cementos      15.0
# 3                             Adhesivo Crest Blanco x 20 kg                Pegantes Cerámicos      19.0
# 4  Paquete de Cople PVC Sanitario 50mm - 2" Cementar x 5 un  Accesorios Sanitaria/Ventilación       4.0
# 5           Pintura Aerosol Blanco Brillante Pabla x 400 mL                 Pinturas en Spray       9.0
#
# kit número  3
# porcentaje de compra  0.11588785046728972
#                                               name                         category  quantity
# 0  Pintura Aerosol Blanco Brillante Pabla x 400 mL                Pinturas en Spray       9.0
# 1   Pintura Aerosol Negro Brillante Paneg x 400 mL                Pinturas en Spray      10.0
# 2             Paquete de Codo 90° CPVC 1/2" x 5 un  Accesorios CPVC - Agua Caliente       6.0
# 3   Paquete de Codo De Cobre 90° C.C. 1/2" x 5 und                      Tubos Cobre       5.0
# 4                   Tubo CPVC RD13.5 3/4" x 3.05 m       Tubos CPVC - Agua Caliente      10.0
# 5                    Tubo CPVC RD13.5 1/2" x 6.1 m       Tubos CPVC - Agua Caliente       7.0
#
# kit número  4
# porcentaje de compra  0.1205607476635514
#                                                   name              category  quantity
# 0               Cemento Cruz Azul x 20 un (1 Tonelada)              Cementos      14.0
# 1  Cemento Gris Tolteca Extra CPC x 20 un (1 Tonelada)              Cementos       2.0
# 2               Varilla G42 - 1/2" x 12 m (1 Tonelada)              Varillas       2.0
# 3               Varilla G42 - 3/8" x 12 m (1 Tonelada)              Varillas       3.0
# 4                            Castillo 15 x 20 cm x 6 m      Vigas y Perfiles      17.0
# 5          Malla electrosoldada 10x10 cm x 6 mm x 40 m  Malla electrosoldada       4.0
#
# kit número  5
# porcentaje de compra  0.21869158878504674
#                                                   name            category  quantity
# 0           Cemento Gris Tolteca Extra CPC 30R x 50 kg            Cementos      15.0
# 1               Cemento Mortero Óptimo Tolteca x 50 kg            Cementos       7.0
# 2                                  Yeso Blanco x 40 kg       Yesos y Cales       8.0
# 3  Cemento Gris Tolteca Extra CPC x 20 un (1 Tonelada)            Cementos       2.0
# 4                              Varilla 3/8" G42 x 12 m            Varillas      72.0
# 5                           Yeso las Golondrinas 36 kg  Estucos Interiores       9.0
#
# kit número  6
# porcentaje de compra  0.09439252336448598
#                                                   name                          category  quantity
# 0                                Clavos 2-1/2" x 25 kg                         Puntillas       2.0
# 1                              Varilla 1/2" G42 x 12 m                          Varillas      21.0
# 2       Estribo 10 x 25 cm x 10 kg (+/- 0.05%) (50 un)                 Estribos / Flejes       5.0
# 3  Paquete de Tee Sanitario Cementar 110mm - 4" x 5 un  Accesorios Sanitaria/Ventilación       2.0
# 4               Varilla G42 - 3/8" x 12 m (1 Tonelada)                          Varillas       3.0
# 5              Tubo Rígido De Cobre Tipo M 1/2 " x 6 m                       Tubos Cobre       4.0
#
# kit número  7
# porcentaje de compra  0.13800623052959501
#                                                   name           category  quantity
# 0               Cemento Mortero Óptimo Tolteca x 50 kg           Cementos       7.0
# 1           Cemento Gris Tolteca Extra CPC 30R x 50 kg           Cementos      15.0
# 2  Cemento Gris Tolteca Extra CPC x 20 un (1 Tonelada)           Cementos       2.0
# 3                            Castillo 15 x 20 cm x 6 m   Vigas y Perfiles      17.0
# 4         Estribo 10 x 20 cm x 9 kg (+/-0.05%) (50 un)  Estribos / Flejes       5.0
# 5       Estribo 10 x 25 cm x 10 kg (+/- 0.05%) (50 un)  Estribos / Flejes       5.0
#
# kit número  8
# porcentaje de compra  0.11090342679127727
#                                                   name              category  quantity
# 0       Estribo 10 x 25 cm x 10 kg (+/- 0.05%) (50 un)     Estribos / Flejes       5.0
# 1         Estribo 10 x 20 cm x 9 kg (+/-0.05%) (50 un)     Estribos / Flejes       5.0
# 2          Malla electrosoldada 10x10 cm x 6 mm x 40 m  Malla electrosoldada       4.0
# 3               Cemento Cruz Azul x 20 un (1 Tonelada)              Cementos      14.0
# 4                                Clavos 2-1/2" x 25 kg             Puntillas       2.0
# 5  Cemento Gris Tolteca Extra CPC x 20 un (1 Tonelada)              Cementos       2.0
#
# kit número  9
# porcentaje de compra  0.24485981308411214
#                                                            name                          category  quantity
# 0                       Tubo Sanitario Cementar 75mm - 3" x 6 m                   Tubos Sanitaria       4.0
# 1                   Tubo Sanitario Cementar 40mm - 1-1/2" x 6 m                   Tubos Sanitaria       4.0
# 2  Paquete de Codo 45° PVC Sanitario 110mm - 4" Cementar x 5 un  Accesorios Sanitaria/Ventilación       3.0
# 3                       Tubo Sanitario Cementar 50mm - 2" x 6 m                   Tubos Sanitaria       5.0
# 4                       Tubo Rígido De Cobre Tipo M 1/2 " x 6 m                       Tubos Cobre       4.0
# 5           Paquete de Tee Sanitario Cementar 110mm - 4" x 5 un  Accesorios Sanitaria/Ventilación       2.0
#
# kit número  10
# porcentaje de compra  0.18504672897196262
#                                              name           category  quantity
# 0                 Alambre recocido Cal 16 x 50 kg           Alambres       4.0
# 1                         Varilla 1/2" G42 x 12 m           Varillas      21.0
# 2                       Castillo 15 x 20 cm x 6 m   Vigas y Perfiles      17.0
# 3          Varilla G42 - 3/8" x 12 m (1 Tonelada)           Varillas       3.0
# 4    Estribo 10 x 20 cm x 9 kg (+/-0.05%) (50 un)  Estribos / Flejes       5.0
# 5  Estribo 10 x 25 cm x 10 kg (+/- 0.05%) (50 un)  Estribos / Flejes       5.0
#
# kit número  11
# porcentaje de compra  0.09314641744548287
#                                                               name                          category  quantity
# 0                   Paquete de Codo De Cobre 90° C.C. 1/2" x 5 und                       Tubos Cobre       5.0
# 1                          Tubo Rígido De Cobre Tipo M 1/2 " x 6 m                       Tubos Cobre       4.0
# 2                             Paquete de Codo 90° CPVC 1/2" x 5 un   Accesorios CPVC - Agua Caliente       6.0
# 3  Paquete de Codo 90° PVC Sanitario 40mm - 1-1/2" Cementar x 5 un  Accesorios Sanitaria/Ventilación       6.0
# 4         Paquete de Cople PVC Sanitario 50mm - 2" Cementar x 5 un  Accesorios Sanitaria/Ventilación       4.0
# 5              Paquete de Tee Sanitario Cementar 110mm - 4" x 5 un  Accesorios Sanitaria/Ventilación       2.0
#
# kit número  12
# porcentaje de compra  0.13271028037383178
#                                                            name                          category  quantity
# 0                                Tubo CPVC RD13.5 3/4" x 3.05 m        Tubos CPVC - Agua Caliente      10.0
# 1                                 Tubo CPVC RD13.5 1/2" x 6.1 m        Tubos CPVC - Agua Caliente       7.0
# 2  Paquete de Codo 45° PVC Sanitario 110mm - 4" Cementar x 5 un  Accesorios Sanitaria/Ventilación       3.0
# 3                          Paquete de Codo 90° CPVC 1/2" x 5 un   Accesorios CPVC - Agua Caliente       6.0
# 4           Paquete de Tee Sanitario Cementar 110mm - 4" x 5 un  Accesorios Sanitaria/Ventilación       2.0
# 5                   Tubo Sanitario Cementar 40mm - 1-1/2" x 6 m                   Tubos Sanitaria       4.0
#
# kit número  13
# porcentaje de compra  0.19376947040498443
#                                          name          category  quantity
# 0                     Varilla 3/8" G42 x 12 m          Varillas      72.0
# 1                   Castillo 15 x 20 cm x 6 m  Vigas y Perfiles      17.0
# 2                     Varilla 1/2" G42 x 12 m          Varillas      21.0
# 3      Cemento Mortero Óptimo Tolteca x 50 kg          Cementos       7.0
# 4      Cemento Cruz Azul x 20 un (1 Tonelada)          Cementos      14.0
# 5  Cemento Gris Tolteca Extra CPC 30R x 50 kg          Cementos      15.0
#
# kit número  14
# porcentaje de compra  0.10186915887850467
#                                                               name                          category  quantity
# 0                          Tubo Rígido De Cobre Tipo M 1/2 " x 6 m                       Tubos Cobre       4.0
# 1                   Paquete de Codo De Cobre 90° C.C. 1/2" x 5 und                       Tubos Cobre       5.0
# 2                           Varilla G42 - 1/2" x 12 m (1 Tonelada)                          Varillas       2.0
# 3     Paquete de Codo 45° PVC Sanitario 110mm - 4" Cementar x 5 un  Accesorios Sanitaria/Ventilación       3.0
# 4      Paquete de Codo 90° PVC Sanitario 50mm - 2" Cementar x 5 un  Accesorios Sanitaria/Ventilación       5.0
# 5  Paquete de Codo 90° PVC Sanitario 40mm - 1-1/2" Cementar x 5 un  Accesorios Sanitaria/Ventilación       6.0
#
# kit número  15
# porcentaje de compra  0.12398753894080997
#                                                               name                          category  quantity
# 0                                       Yeso las Golondrinas 36 kg                Estucos Interiores       9.0
# 1                           Cemento Mortero Óptimo Tolteca x 50 kg                          Cementos       7.0
# 2                       Cemento Gris Tolteca Extra CPC 30R x 50 kg                          Cementos      15.0
# 3                          Tubo Rígido De Cobre Tipo M 1/2 " x 6 m                       Tubos Cobre       4.0
# 4         Paquete de Cople PVC Sanitario 50mm - 2" Cementar x 5 un  Accesorios Sanitaria/Ventilación       4.0
# 5  Paquete de Codo 90° PVC Sanitario 40mm - 1-1/2" Cementar x 5 un  Accesorios Sanitaria/Ventilación       6.0

# %%
categories = set([ products[i]['category'] for j in kits for i in j])
print(len(categories))
# Out:
# 16
