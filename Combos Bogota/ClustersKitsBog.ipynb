# %% [markdown]
# # Análisis de similitud entre clientres y combos por zonas

# %%
import pandas as pd

# %%
# Se leen los resultados
lift = pd.read_excel('result.xlsx', sheet_name = 'lift').to_dict(orient = 'index')
lift = { (lift[i]['product_a'], lift[i]['product_b']): lift[i]['lift']  for i in lift}
products = pd.read_excel('result.xlsx', sheet_name = 'products', index_col = 'id').to_dict(orient = 'index')

# %%
# Para cada producto se saca el kit representativo.
kits = []

for i in products:
    scores = [(100,i)]
    for j in products:
        try:
            scores.append((lift[i,j],j))
        except:
            scores.append((0,j))
    
    scores.sort(reverse = True)
    testKit = [ i[1] for i in scores[0:6] ]
    
    # Se eliminan kits repetidos
    inside = False
    for k in kits:
        if len(set(testKit).intersection(set(k))) > 3:
            inside = True
    
    if inside == False:
        kits.append([ i[1] for i in scores[0:6]])

print('Se crearon ', len(kits), ' kits')
# Out:
# Se crearon  4  kits

# %%
# Ahora se imprimen los kits con sus respectivas cantidades a comprar
pd.set_option('display.max_colwidth', 1000)

n = 1
for i in kits:
    
    print("\t")
    print('kit número ', n)
    print('porcentaje de compra ', sum([products[j]['orders'] for j in i])/6/3990)
    name = [ products[j]['name'] for j in i ]
    category = [ products[j]['category'] for j in i ]
    quantity = [ round(products[j]['avg'],0) for j in i ]
    
    display(pd.DataFrame({'name': name, 'category': category, 'quantity': quantity}))
    n += 1
# Out:
#
# kit número  1
# porcentaje de compra  0.24068504594820386
#                                                name                  category  \
# 0                Masilla Supermastick Balde X 14 kg                  Masillas
# 1                Masilla Supermastick Galón X 5.6Kg                  Masillas
# 2                 Masilla Supermastick Caja X 28 Kg                  Masillas
# 3       Vinilo Fino Blanco Tipo 1 x 2.5 Gal / Balde  Pinturas para interiores
# 4  Vinilo Tipo 2 Corriente Blanco x 2.5 Gal / Balde  Pinturas para interiores
# 5               Masilla Supermastick Cuñete x 28 Kg                  Masillas
#
#    quantity
# 0       5.0
# 1       8.0
# 2       8.0
# 3       3.0
# 4       9.0
# 5       9.0
#
# kit número  2
# porcentaje de compra  0.13375104427736006
#                                             name                category  \
# 0  Perfil Entrepiso Hot Rolled x 6m - Esp 1.40mm  Perfiles Estructurales
# 1                     Varilla G-60 W 11 Mm 6 Mts                Varillas
# 2              Varilla g-60 W 9 mm x6m Corrugada                Varillas
# 3              Varilla Corrugada G-60 12mm x 6 m                Varillas
# 4                    Varilla Corrugada 12mm x 6m                Varillas
# 5               Varilla corrugada G60 1/2" x 6 m                Varillas
#
#    quantity
# 0      22.0
# 1     123.0
# 2     111.0
# 3     138.0
# 4     101.0
# 5     147.0
#
# kit número  3
# porcentaje de compra  0.35969089390142023
#                                             name                category  \
# 0    Cemento Super Resistente Presentación 50 kg                Cementos
# 1                              Cemento UG x 50Kg                Cementos
# 2              Varilla g-60 W 9 mm x6m Corrugada                Varillas
# 3                          Cemento Tipo Ug 50 kg                Cementos
# 4                Cemento Uso General Gris x 50kg                Cementos
# 5  Perfil Entrepiso Hot Rolled x 6m - Esp 1.40mm  Perfiles Estructurales
#
#    quantity
# 0      38.0
# 1      28.0
# 2     111.0
# 3      33.0
# 4      13.0
# 5      22.0
#
# kit número  4
# porcentaje de compra  0.11436925647451963
#                                  name                     category  quantity
# 0                         Sika 1 1 kg  Aditivos Impermeabilizantes       5.0
# 1    Sikaflex Universal Gris x 300 mL                    Siliconas       5.0
# 2  Sikaflex Universal Blanco x 300 mL                    Siliconas       5.0
# 3                   Cemento UG x 50Kg                     Cementos      28.0
# 4   Varilla Corrugada G-60 12mm x 6 m                     Varillas     138.0
# 5   Varilla g-60 W 9 mm x6m Corrugada                     Varillas     111.0

# %%
categories = set([ products[i]['category'] for j in kits for i in j])
print(len(categories))
# Out:
# 7
